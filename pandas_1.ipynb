# %%
import pandas as pd

# %%
pf = pd.read_csv("survey_results_public.csv")

# %%
###display the desired rows and columns of the table:

# %%
pf
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
pf.loc[6]  #This line selects the row at index position 6 in our csv 'pf'.
# Out:
# ResponseId                                                             7
# Q120                                                             I agree
# MainBranch                                I am a developer by profession
# Age                                                      35-44 years old
# Employment                                           Employed, full-time
#                                              ...
# ProfessionalTech       Microservices;Automated testing;Continuous int...
# Industry               Information Services, IT, Software Development...
# SurveyLength                                       Appropriate in length
# SurveyEase                                                          Easy
# ConvertedCompYearly                                             135000.0
# Name: 6, Length: 84, dtype: object

# %%
pf.loc[[2,4]]  #This line selects rows with indexes 2 and 4 from the 'pf'.
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 2           3  I agree  I am a developer by profession  45-54 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 2                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 2  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                     CodingActivities  \
# 2  Hobby;Professional development or self-paced l...
# 4  Hobby;Contribute to open-source projects;Profe...
#
#                                         EdLevel  \
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 2  Books / Physical media;Colleague;On the job tr...
# ...

# %%
pf.iloc[0:7,0:7]  #This line contains rows and columns from index postions 0 to 6.
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
# 5           6  I agree  I am a developer by profession  35-44 years old
# 6           7  I agree  I am a developer by profession  35-44 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
# ...

# %%
###assign indexing to a specific column of the table:

# %%
pf.set_index('Country') #This line sets the specific column as index.
# Out:
#                               ResponseId     Q120  \
# Country
# NaN                                    1  I agree
# United States of America               2  I agree
# United States of America               3  I agree
# United States of America               4  I agree
# Philippines                            5  I agree
# ...                                  ...      ...
# Brazil                             89180  I agree
# Romania                            89181  I agree
# Israel                             89182  I agree
# Switzerland                        89183  I agree
# Iran, Islamic Republic of...       89184  I agree
#
#                                                   MainBranch  \
# Country
# NaN                                            None of these
# United States of America      I am a developer by profession
# United States of America      I am a developer by profession
# United States of America      I am a developer by profession
# ...

# %%
pf.reset_index(drop=True, inplace=True) #We can also return the default indexing with this line.
pf
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# ...

# %%
###create a filter based on 2 parameters. Print the appropriate table:

# %%
filt = pf['Country'] == 'Georgia'

# %%
filt2 = pf['Age']  <20

# %%
filts = filt & filt2

# %%
pf.loc[filts,['Country','Age']]
# Out:
#        Country  Age
# 421    Georgia   18
# 502    Georgia   18
# 739    Georgia   18
# 818    Georgia   18
# 1673   Georgia   18
# ...        ...  ...
# 86064  Georgia   18
# 87400  Georgia   18
# 87733  Georgia   18
# 88409  Georgia   18
# 89027  Georgia   18
#
# [166 rows x 2 columns]

# %%
###Sort the table using the 2 parameter

# %%
pf.sort_values(by=["Country", 'EdLevel']) #this sorts data by these two columns
pf.sort_index() #we can also add sort_index which will sort the data by index
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# ...

# %%
###use Statistical functions (mean, standard deviation, median, min, max):

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df['ConvertedCompYearly'].mean()
# Out:
# 103110.08171765343

# %%
df['ConvertedCompYearly'].max()
# Out:
# 74351432.0

# %%
df['ConvertedCompYearly'].min()
# Out:
# 1.0

# %%
df['ConvertedCompYearly'].std()
# Out:
# 681418.8387120209

# %%
df['ConvertedCompYearly'].median()
# Out:
# 74963.0

# %%
###Build different types of graphs (eg. Bar and line charts):

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 5*np.pi, 0.1)
y1 = np.sin(x)             #This is the day i finally used sin,cos and tan <33
y2 = np.cos(x)
plt.plot(x, y1, color='purple')
plt.plot(x, y2, color='darkblue')
plt.show()

# %%
x = np.arange(0, 5*np.pi, 0.1)
y = np.tan(x)
plt.plot(x, y, color='green')
plt.show()

# %%
import matplotlib.pyplot as plt

# Selecting the top 10 countries with the highest 'ConvertedCompYearly' values
top_10 = plot.nlargest(10, 'ConvertedCompYearly')

plt.bar(
    x=top_10['Country'],
    height=top_10['ConvertedCompYearly']
)

plt.xlabel('Country')
plt.ylabel('Mean ConvertedCompYearly')
plt.title('Top 10 Countries by Mean ConvertedCompYearly')

plt.xticks(rotation=90)
plt.show()
